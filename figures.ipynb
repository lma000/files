# %% [markdown]
# ### no noise vs noise
#
# cv = 0,0.2

# %% [markdown]
# shows that theta oscillations vanish upon introduction of noise to (non oscillatory) inputs
#
# plots show histograms and spike rasters of fast INs vs slow INs

# %% [markdown]
# ffts of the above spike data

# %% [markdown]
# ### phasic input (noise vs no noise)
#
# sigma = 0,pi/8,pi/4
# cv = 0,0.2

# %% [markdown]
# comparing noisy and non noisy oscillatory inputs (8 hz), sigmas are stdevs for phase dispersion

# %% [markdown]
# ### vector strengths
# normal sigma = 0,pi/8,pi/4 on fast, slow, slow->fast
# uniform range 0,pi/2,pi,2pi on fast, slow (lost these values somewhere lol I'll plot them when I find them again)

# %% [markdown]
# map spikes within an osc period to the unit circle and average them for each neuron
#
# vector strengths are a metric of coherence of the direction they point in on average
#
# 1 means they all point in the same direction, 0 means they're completely randomly distributed
#
# vector strengths plotted for sinusoidal input to fast only vs slow only vs slow transformed to fast

# %%
0 pi/8 pi/4 in order, f then s

0.7984354535926785 0.9424284110901485

0.5843418318971993 0.8754114635565577

0.6492790969925616 0.7072242470673941
